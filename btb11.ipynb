# %%
#1
a, b = map(int, input().split())
try:
  print(a/b)
except ZeroDivisionError:
  print('Loi chia khong')
# Out:
# 3 2
# 1.5

# %%
#2
my_list = [int(x) for x in input().split()]
n = len(my_list)
try:
  print(my_list[n])
except IndexError:
  print('Truy cap chi so sai')
# Out:
# Truy cap chi so sai

# %%
#3
def square_digit_sum(n:int)->int:
  ans = 0
  while n:
    ans += (n%10) * (n%10)
    n//=10
  return ans

def is_happy(n:int) -> int:
  exist = {}
  exist[n] = True
  while n!=1:
    n = square_digit_sum(n)
    if n in exist:
      return 'NO'
    exist[n] = True
  return 'YES'

a = 0

while True:
  try:
    a = int(input())
    break
  except ValueError:
    pass

print(is_happy(a))
# Out:
# 19
# YES

# %%
#4
try:
  a, b = map(int, input().split())
  print(a+b)
except ValueError:
  print('Nhap sai kieu du lieu.')
finally:
  print('Ket thuc chuong trinh.')
# Out:
# a 1
# Nhap sai kieu du lieu.
# Ket thuc chuong trinh.

# %%
#5
a = [x for x in input().split()]
for i in range(len(a)):
  try:
    a[i] = int(a[i])
  except ValueError:
    print('Phan tu', i+1, 'khong the chuyen duoc sang int.')
print(a)
# Out:
# 12 a 34 7 b
# Phan tu 2 khong the chuyen duoc sang int.
# Phan tu 5 khong the chuyen duoc sang int.
# [12, 'a', 34, 7, 'b']

# %%
#6
import math
try:
  x = int(input())
  print(f"{math.sqrt(x):.2f}")
except ValueError:
  print('So am')
# Out:
# 2
# 1.41

# %%
#7
try:
    age = int(input().strip())
    if age <= 0:
        print("Tuoi khong hop le")
    else:
        print(2025 - age)
except:
    print("Tuoi khong hop le")

# %%
#8
s = input()
txt = '.txt'
zip = '.zip'
is_txt = True
is_zip = True
try:
  for i in range(-1, -5, -1):
    if s[i].lower() != txt[i]:
      is_txt = False
      break
  for i in range(-1, -5, -1):
    if s[i].lower() != zip[i]:
      is_zip = False
      break
  if is_txt or is_zip:
    print('Doc file thanh cong')
  else:
    print('File khong hop le')
except IndexError:
    print('File khong hop le')
# Out:
# README.TXT
# Doc file thanh cong

# %%
#9
s = input()
try:
  print(int(s))
except ValueError:
  print('Chuoi khong hop le')
# Out:
# abc
# Chuoi khong hop le

# %%
#10
a = [int(x) for x  in input().split()]
exist = {}
valid = True
for i in a:
  if i in exist:
    valid = False
    break
  exist[i] = True
if valid:
  ans = 0
  for i in a:
    ans += i
  print(ans)
else:
  print('Mang khong hop le')
# Out:
# 1 1 2 3
# Mang khong hop le

# %%
#11
import re
q = int(input())
for i in range(q):
  s = input()
  try:
    re.compile(s)
    print(True)
  except re.error:
    print(False)
# Out:
# 1
# .*\+
# True
