# %%
#1
def reverse(n):
    res = 0
    while n > 0:
        res = res * 10 + n%10
        n //= 10
    return res
num = 0
with open("input.txt","r") as file: 
    num = file.read() 
num = int(num)
print(reverse(num))
# Out:
# 321

# %%
#2
def check(n):
    if n%4 == 0: return ("Thua") # cứ nếu n chia hết cho 4, thì do mình phải chọn trước nên friend luôn có cách khiến mình thua
    return ("Thang")
num = 0
with open("input.txt","r") as file: 
    num = file.read()
num = int(num)
print(check(num))
# Out:
# Thang

# %%
#3
with open("input.txt","r") as file: 
    n = int(file.readline())
    for i in range(n): 
        name = file.readline()
        print(name.strip()) # loai bo ky tu xuong dong
# Out:
# Argus Filch
# Firenze
# Gilderoy Lockhart

# %%
#4
def check(i):
    return (i >='a' and i<='z') or (i>='A' and i <='Z') 
with open("input.txt", "r") as file: 
    s1 = file.readline()
    s2 = file.readline()
    count_char = 0
    # chuan hoa 2 xau
    s1 = s1.lower()
    s2 = s2.lower()
    for i in s1: 
        if check(i) and i != " ": 
            count_char += 1
    print(count_char)
    for i in s2: 
        if i in s1 and i != " ":
            count_char -= 1
    if count_char == 0:
        print(True)
    else: 
        print(False)
# Out:
# 16
# True

# %%
#5
def count(s, k): 
    c = 0
    for i in s: 
        if i == k: 
            c += 1
    return c
with open("input.txt","r") as file: 
    s = file.readline()
    ch = file.readline()
    print(count(s,ch))
# Out:
# 9

# %%
#6
def count(s, k): 
    c = 0
    for i in s: 
        if i == k: 
            c += 1
    return c
with open("input.txt","r") as file: 
    s = file.readline()
    ch = file.readline()
    s = s.lower()
    print(count(s,ch))
# Out:
# 7

# %%
#7
try: 
    with open("input.txt","r") as file: 
        print("YES")
except: 
    print("NO")
# Out:
# NO

# %%
#8 
f = [0] * 21
f[0] = 'a'
f[1] = 'b'
for i in range(2,20 + 1):
    f[i] = f[i-1] + f[i-2] 
with open("input.txt", "r") as file: 
    n = int(file.read())

with open("output.txt", "w") as file: 
    for i in range(0,n):
        file.write(f"{f[i]}\n") 
        #   output must be a string

# %%
#9 
# REWORK?
with open("input.txt", "r") as file: 
    s = file.readlines()
     # bo qua dong tieu de
    for k in range(1,len(s)):
        i = s[k]
        i = i.split(" ")
        ho = i[1].strip()
        ten = i[2].strip()
        thcs4 = i[5].strip()
        if int(thcs4) == 10: 
            print(ho, ten)
# Out:
# Chu Chi

# %%
#10 
def getMoney(s): 
    s = s.split(" ")
    res = []
    for i in s: 
        res.append(int(i))
    return res
def rob(lst): 
    prev2 = 0
    prev1 = 0
    
    for money in lst:
        current = max(prev2 + money, prev1)
        prev2 = prev1
        prev1 = current
    return prev1


arr = []
with open("input.txt","r") as file: 
    s = file.read()
arr = getMoney(s)

# %%
#11

try: 
    with open("input.txt","r") as file: 
        s = file.read().split()
        #s = s.replace('/',' ') ??? 
        maxi = 0
        mini = 1e10
        for i in s:
            maxi = max(maxi,int(i))
            mini = min(mini, int(i))
        print(maxi, mini) 
except: 
    print("Mission failed")
# Out:
# ['1', '2', '4', '2', '45', '5', '4']
# 45 1

# %%
#12

with open("input.txt","r") as file: 
    n = int(file.readline())
    s = file.readline()
    s = s.split(" ")
    lst = [int(i) for i in s]
    lst.sort(reverse=True)
    power = lst[0] * lst[1] * lst[2]
    print(power)
# Out:
# 80

# %%
#13
try:
    with open("input.txt","r") as file: 
        n = int(file.readline())
        s = file.readline()
        s = s.split(" ")
        lst = [int(i) for i in s]
        res = []
        c = 0
        for i in lst: 
            if i != 0:
                res.append(i)
            else: 
                c += 1
        res = res + [0] * c
    with open("output.txt","w") as file: 
        file.write(str(res))
except:
    print("No file found")

# %%
#14
def avarage(s,c): 
    return (f"{s/c:.2f}")
with open("Frank.csv", "r") as file: 
    s = file.readlines()
    sum = 0
    c = 0
    for i in s: 
        #print(i.strip()) loai bo ky tu xuong dong
        lap, time = i.split(',') # tach string 
        time = time.strip() # loại bỏ ký tự xuống dòng
        sum += float(time)
        c += 1
    print(avarage(sum,c))
# Out:
# 138.68

# %%
#15

with open("input.txt", "r") as file: 
    s = file.readlines()
    check = False
    for i in range(1,len(s)): # đọc từ dòng 1 trở đi
        #print(i.strip()) loai bo ky tu xuong dong
        id,movie,description, rating = s[i].split(',') # tach string 
        rating = (rating.strip()) # loại bỏ ký tự xuống dòng
        
        if float(rating) >= 8.0 and description != "boring": 
            print(movie)
            check = True

if not check: 
    with open("output.txt", "w") as file: 
        file.write("NO")
# Out:
#  Thor
#  Ice song

# %%
#16
import math
with open("input.txt", "r") as file: 
    s = file.readlines()
    lst = [lst.strip() for lst in s if lst.strip()]
    for i in range(0,len(lst),2):
        type = lst[i]
        data = lst[i+1]
        shape = type.split(":")[1].strip().upper() # lấy tên loại hình

        if shape == "SQUARE": 
            side = data.split(":")[1]
            print( f"{4 * float(side):.2f}")    
        elif shape == "RECTANGLE": 
            side = data.replace(":", " ")
            parts = side.split() 
            width = float(parts[1])
            height = float(parts[3])
            print(f"{2 * (width + height):.2f}")
        elif shape == "CIRCLE": 
            radius = data.split(":")[1]
            print(f"{2 * math.pi*float(radius):.2f}")
# Out:
# 21.20
# 42.00
# 13.51

# %%
#17
def power(arr, i): 
    tem = 1 
    for j in range(0,len(arr)):
        if j == i:
            continue
        else: 
            tem *= arr[j]
    return tem
with open("input.txt", "r") as file: 
    n = file.readline()
    s = file.readline()
    s = s.split() # always have this step 
    lst = [int(n) for n in s]
    res = []
    for i in range(0,len(lst)): 
        res.append(power(lst,i))
    print(res)
# Out:
# [120, 80, 240, 96, 240]

# %%
#19 
    #REWORK
import struct 
try: 
    with open("input.txt", "rb") as file: 
        s = file.read()
        n = len(s) // 8 # 1 double / 8 byte
        tem = f"{n}d"
        num = struct.unpack(tem,s)
        for i in num: 
            print(f"{i}") 
except: 
    pass

# %%
#20
#REWORK
import math

try:
    with open("input.txt", "r") as file:
        s = file.read().split()
        M = int(s[0])
        raw = [int(x) for x in s[1:]]
        img = []
        for i in range(M):
            img.append(raw[i*M : (i+1)*M])
        res = [[0] * M for _ in range(M)]
        for r in range(M):
            for c in range(M):
                sum = 0
                count = 0
                for i in range(r - 1, r + 2):
                    for j in range(c - 1, c + 2):
                        if 0 <= i < M and 0 <= j < M:
                            sum += img[i][j]
                            count += 1
                res[r][c] = sum // count
        for row in res:
            print(*(row))
            
except:
    print("Mission failed")
